# %% [markdown]
# ### The method for inverse distance
#
# In this notebook, I calculate the distance-weighted number of R1/R2 universities
#
# The method is as follows:
#
# - I find out longitudes and latitudes of all the R1/R2 universities in MA and all four nearby states (NY, CT, NH, RI).
# - For the MA scenario, there are 38 universities I have to consider. (38 universities distributed in MA, NY, CT, NH, RI.)
# - Then for each school district (call it District #1), I calculate the inverse distance quantities for District #1 with each of the 38 universities. I then sum over all 38 of them. This sum is interpreted as the distance-weighted number of R1/R2 universities for the District #1.
# - To be specific about point (3), the inverse distance quantity between a school district and a university is calculated as
#
# \begin{equation}
#     {\rm inverse~distance~quantity} = \frac{1}{ \frac{\rm distance}{\rm 10~miles} + 1}
# \end{equation}
#
# - After points (3) and (4), I then repeat the same calculation for the second district (District #2), the third district (District #3), ...., all the way to the last district in MA.
# - After all the calculations are done, I add all the inverse distance quantities into the existing dataframe. I call this new column the "Inverse Distance R1R2".
#
#
#
# Note that the softening factor I used for MA is 10 miles. The reason for choosing this value is because:
# - The typical school district size in MA is about 10 miles wide,
# - I imagine the typical commute distance in MA is roughly 10 miles
# - For other states such as GA or WI, a proper values can be the typical size of the county in that state.
# 10 miles as the softening factor for GA and WI may be too small as GA and WI are big states.

# %%
import pandas as pd
import numpy as np
from geopy import distance

# %%
MA_district_coordinates = pd.read_excel('data/MA_AP_performance/MA_district_coordinates.xlsx')

def distance_district_univeristy(district_name, university_name):
    district_coor = MA_district_coordinates[MA_district_coordinates['District Name'] == district_name][['LONGITUD', 'LATITUDE']].to_numpy()[0][::-1]
    university_coor = university_coordinate_df[university_coordinate_df['INSTNM'] == university_name][['LONGITUD', 'LATITUDE']].to_numpy()[0][::-1]
    
    return distance.distance(district_coor, university_coor).miles    ## return unit is miles

def inverse_distance_weight(distance_miles):
    '''
    The softening factor I used for MA is 10 miles. The reason for choosing this value is because:
    (1) The typical school district size in MA is about 10 miles wide, 
    (2) I imagine the typical commute distance in MA is roughly 10 miles

    For other states such as GA or WI, a proper values can be the typical size of the county in that state.
    10 miles as the softening factor for GA and WI may be too small as GA and WI are big states.
    '''
    epsilon_soften_factor = 10.0  ## [miles]
    
    return 1.0 / ( (distance_miles/epsilon_soften_factor) + 1.0 )     ## there is no return unit

# %%
## search R1/R2 universities in MA and all four nearby states (NY, CT, NH, RI)
state_name_abbrev_arr = ['MA', 'NY', 'CT', 'NH', 'RI', 'ME', 'VT', 'NH']
university_coordinate_df = []

for state_abbrev in state_name_abbrev_arr:
    university_coordinate_df += [pd.read_excel('data/MA_AP_performance/hd2023_coordinate/hd2023_R1R2_data_%s.xlsx'%state_abbrev)]
university_coordinate_df = pd.concat(university_coordinate_df, ignore_index=True)

university_coordinate_df
# Out:
#     UNITID                                             INSTNM  \
# 0   164924                                     Boston College
# 1   164988                                  Boston University
# 2   165015                                Brandeis University
# 3   165334                                   Clark University
# 4   166027                                 Harvard University
# 5   166513                 University of Massachusetts-Lowell
# 6   166629                University of Massachusetts-Amherst
# 7   166638                 University of Massachusetts-Boston
# 8   166683              Massachusetts Institute of Technology
# 9   167358                            Northeastern University
# 10  167987              University of Massachusetts-Dartmouth
# 11  168148                                   Tufts University
# 12  168421                    Worcester Polytechnic Institute
# 13  190044                                Clarkson University
# 14  190150        Columbia University in the City of New York
# 15  190415                                 Cornell University
# 16  190567                                  CUNY City College
# 17  190576         CUNY Graduate School and University Center
# 18  191241                                 Fordham University
# 19  192448                             Long Island University
# 20  193654                                     The New School
# 21  193900                                New York University
# 22  194824                   Rensselaer Polytechnic Institute
# 23  195003                  Rochester Institute of Technology
# 24  195030                            University of Rochester
# 25  196060                               University at Albany
# 26  196079                              Binghamton University
# 27  196088                              University at Buffalo
# 28  196097                             Stony Brook University
# 29  196103  SUNY College of Environmental Science and Fore...
# 30  196413                                Syracuse University
# 31  196468            Teachers College at Columbia University
# 32  129020                          University of Connecticut
# 33  130794                                    Yale University
# 34  182670                                  Dartmouth College
# 35  183044            University of New Hampshire-Main Campus
# 36  217156                                   Brown University
# 37  217484                         University of Rhode Island
# 38  161253                                University of Maine
# 39  161457                          University of New England
# 40  231174                              University of Vermont
# 41  182670                                  Dartmouth College
# 42  183044            University of New Hampshire-Main Campus
#
#                CITY                                   COUNTYNM State  \
# 0     Chestnut Hill                           Middlesex County    MA
# 1            Boston                             Suffolk County    MA
# 2           Waltham                           Middlesex County    MA
# 3         Worcester                           Worcester County    MA
# 4         Cambridge                           Middlesex County    MA
# 5            Lowell                           Middlesex County    MA
# 6           Amherst                           Hampshire County    MA
# 7            Boston                             Suffolk County    MA
# 8         Cambridge                           Middlesex County    MA
# 9            Boston                             Suffolk County    MA
# 10  North Dartmouth                             Bristol County    MA
# 11          Medford                           Middlesex County    MA
# 12        Worcester                           Worcester County    MA
# 13          Potsdam                        St. Lawrence County    NY
# 14         New York                            New York County    NY
# 15           Ithaca                            Tompkins County    NY
# 16         New York                            New York County    NY
# 17         New York                            New York County    NY
# 18            Bronx                               Bronx County    NY
# 19       Brookville                              Nassau County    NY
# 20         New York                            New York County    NY
# 21         New York                            New York County    NY
# 22             Troy                          Rensselaer County    NY
# 23        Rochester                              Monroe County    NY
# 24        Rochester                              Monroe County    NY
# 25           Albany                              Albany County    NY
# 26           Vestal                              Broome County    NY
# 27          Buffalo                                Erie County    NY
# 28      Stony Brook                             Suffolk County    NY
# 29         Syracuse                            Onondaga County    NY
# 30         Syracuse                            Onondaga County    NY
# 31         New York                            New York County    NY
# 32           Storrs                    Capitol Planning Region    CT
# 33        New Haven  South Central Connecticut Planning Region    CT
# 34          Hanover                             Grafton County    NH
# 35           Durham                           Strafford County    NH
# 36       Providence                          Providence County    RI
# 37         Kingston                          Washington County    RI
# 38            Orono                           Penobscot County    ME
# 39        Biddeford                                York County    ME
# 40       Burlington                          Chittenden County    VT
# 41          Hanover                             Grafton County    NH
# 42           Durham                           Strafford County    NH
#
#      LONGITUD   LATITUDE  R1R2  Annual enrollment  Number of dorm beds
# 0  -71.169242  42.336213  True              16502                 7611
# 1  -71.107942  42.351118  True              42047                10551
# 2  -71.260155  42.365727  True               6403                 2950
# 3  -71.823356  42.249987  True               3880                 1523
# 4  -71.118313  42.374471  True              41024                13694
# 5  -71.326809  42.652864  True              22192                 4787
# 6  -72.526728  42.385999  True              35781                14015
# 7  -71.036865  42.312881  True              19107                 1077
# 8  -71.093226  42.359243  True              12195                 5965
# 9  -71.088782  42.339992  True              30003                10011
# 10 -71.004552  41.628690  True               9491                 4016
# 11 -71.118293  42.408550  True              13458                 4070
# 12 -71.808339  42.274853  True               7654                 2217
# 13 -74.999359  44.662716  True               4697                 2482
# 14 -73.961885  40.808286  True              33882                12459
# 15 -76.483084  42.447200  True              24594                 7135
# 16 -73.948542  40.819846  True              18546                  589
# 17 -73.983822  40.748612  True              10413                  111
# 18 -73.882705  40.859354  True              19139                 4842
# 19 -73.593678  40.820714  True              18544                 2520
# 20 -73.997114  40.735508  True              12046                 2172
# 21 -73.997264  40.729452  True              58361                12985
# 22 -73.676646  42.729978  True               8256                 3930
# 23 -77.673860  43.084188  True              18231                 6527
# 24 -77.631202  43.126397  True              14171                 1350
# 25 -73.824662  42.685489  True              20099                 6551
# 26 -75.966889  42.087868  True              19660                 7092
# 27 -78.789458  43.000942  True              35509                 7962
# 28 -73.120460  40.914760  True              34115                10474
# 29 -76.138724  43.034765  True               2385                  620
# 30 -76.133989  43.036644  True              38868                 8001
# 31 -73.960194  40.810216  True               5845                  700
# 32 -72.249948  41.809098  True              29818                12040
# 33 -72.926688  41.311158  True              14910                 5576
# 34 -72.289949  43.704115  True               7171                 3733
# 35 -70.932465  43.135934  True              16001                 6862
# 36 -71.403850  41.826170  True              10807                 4903
# 37 -71.527356  41.484691  True              21108                 6610
# 38 -68.669332  44.899257  True              13426                 3117
# 39 -70.385350  43.458591  True              12232                 1580
# 40 -73.196646  44.477325  True              15903                 5872
# 41 -72.289949  43.704115  True               7171                 3733
# 42 -70.932465  43.135934  True              16001                 6862

# %% [markdown]
# # Calculate inverse distance for each school district in MA

# %%
MA_AP_performance_year = pd.read_excel('data/MA_AP_performance/AP_performance_18_22.xlsx', sheet_name='2022-23').reset_index(drop=True)

inverse_distance_weight_arr = []
for district_name in MA_AP_performance_year['District Name'].tolist():
    total_val = 0
    for university_name in university_coordinate_df['INSTNM'].tolist():
        distance_ij = distance_district_univeristy(district_name, university_name)
        total_val += inverse_distance_weight(distance_ij)
    inverse_distance_weight_arr.append(total_val)

MA_AP_performance_year['Inverse Distance R1R2'] = inverse_distance_weight_arr
MA_AP_performance_year = MA_AP_performance_year.sort_values(by='District Name').reset_index(drop=True)

# %%
MA_AP_performance_year
# Out:
#                                          District Name  District Code  \
# 0                                             Abington          10000
# 1    Academy Of the Pacific Rim Charter Public (Dis...        4120000
# 2                                     Acton-Boxborough        6000000
# 3    Advanced Math and Science Academy Charter (Dis...        4300000
# 4                                               Agawam          50000
# ..                                                 ...            ...
# 282                                         Winchendon        3430000
# 283                                         Winchester        3440000
# 284                                           Winthrop        3460000
# 285                                             Woburn        3470000
# 286                                          Worcester        3480000
#
#     Tests Taken   Score=1   Score=2   Score=3   Score=4   Score=5  \
# 0           164        40        49        51        21         3
# 1           154       120        25         5         3         1
# 2         1,442        22        79       229       473       639
# 3           387        17        51        87       118       114
# 4           423        60       104       140        82        37
# ..          ...       ...       ...       ...       ...       ...
# 282          53        10        16        10        14         3
# 283       1,165        28       115       289       365       368
# 284         319       157        76        54        29         3
# 285         397       103        68       108        79        39
# 286       2,283       860       558       446       277       142
#
#      % Score 1-2  % Score 3-5  Inverse Distance R1R2
# 0           54.3         45.7               5.742173
# 1           94.2          5.8               7.525006
# 2            7.0         93.0               6.292539
# 3           17.6         82.4               6.140166
# 4           38.8         61.2               4.259957
# ..           ...          ...                    ...
# 282         49.1         50.9               4.547397
# 283         12.3         87.7               7.940076
# 284         73.0         27.0               7.601140
# 285         43.1         56.9               7.442246
# 286         62.1         37.9               6.470112
#
# [287 rows x 11 columns]
