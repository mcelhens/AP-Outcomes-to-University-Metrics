# %% [markdown]
# # Cleaning up Indiana's Raw Data

# %%
import pandas as pd

# %%
indiana_raw = pd.read_csv('data/indiana_raw.csv')
# Out:
#   County                         Corp Name  \
# 0   Name                              Name
# 1  Adams   Adams Central Community Schools
# 2  Adams     North Adams Community Schools
# 3  Adams               South Adams Schools
# 4  Allen  MSD Southwest Allen County Schls
#
#                                     Asian  \
# 0  Number of Graduates (in 4 Year Cohort)
# 1                                     NaN
# 2                                     ***
# 3                                     ***
# 4                                      32
#
#                                 Asian.1                             Asian.2  \
# 0  N of Graduates who Passed an AP Exam  N of Graduates who Took an AP Exam
# 1                                   NaN                                 NaN
# 2                                   ***                                 ***
# 3                                   ***                                 ***
# ...

# %%
# taking a look at the Georgia data
import data_loaders
ga_df = data_loaders.gimmeGA('2022')
ga_df.head()
# Out:
#      County  Passing Ratio  Number of Tests  Number of Tests Passed
# 0  Appling        0.193182               88                      17
# 1  Baldwin        0.195238              210                      41
# 2    Banks        0.560000               25                      14
# 3   Barrow        0.554371              469                     260
# 4   Bartow        0.416926             1607                     670
