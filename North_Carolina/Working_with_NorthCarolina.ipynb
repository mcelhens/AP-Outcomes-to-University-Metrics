# %%
import pandas as pd
import numpy as np

from geopy.distance import distance

# %%
carnegie = pd.read_csv('../data/carnegie_with_location.csv')
northcarolina_2023=pd.read_excel('../data/North_Carolina/2023_AP Test Results_2023.xlsx',sheet_name='fortablebysch3yrs_2223_final')
uscounties = pd.read_csv('../data/uscounties.csv')

# %%
import matplotlib.pyplot as plt

# %%
northcarolina_2018=pd.read_excel('../data/North_Carolina/AP_Test_Results_2018.xlsx',sheet_name='2018')
northcarolina_2019=pd.read_excel('../data/North_Carolina/AP_Test_Results_2018.xlsx',sheet_name='2019')
northcarolina_2020=pd.read_excel('../data/North_Carolina/AP_Test_Results_2018.xlsx',sheet_name='2020')

# %%
northcarolina_2021=pd.read_excel('../data/North_Carolina/AP_Test_Results_2021_22.xlsx',sheet_name='2021')
northcarolina_2022=pd.read_excel('../data/North_Carolina/AP_Test_Results_2021_22.xlsx',sheet_name='2022')

# %%
# Filter for county-level rows
county_data_2018 = northcarolina_2018[northcarolina_2018["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data_2018.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2018.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2018.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2018.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2018.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data_2018['County'] = county_data_2018['County'].str.replace(' County', '')
# Display the filtered data
county_data_2018
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2184323094.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2018.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2184323094.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2018.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2184323094.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Filter for county-level rows
county_data_2019 = northcarolina_2019[northcarolina_2019["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data_2019.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2019.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2019.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2019.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2019.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data_2019['County'] = county_data_2019['County'].str.replace(' County', '')
# Display the filtered data
county_data_2019
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2451768048.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2019.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2451768048.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2019.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\2451768048.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Filter for county-level rows
county_data_2020 = northcarolina_2020[northcarolina_2020["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data_2020.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2020.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2020.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2020.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2020.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data_2020['County'] = county_data_2020['County'].str.replace(' County', '')
# Display the filtered data
county_data_2020
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1025641561.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2020.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1025641561.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2020.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1025641561.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Filter for county-level rows
county_data_2021 = northcarolina_2021[northcarolina_2021["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data_2021.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2021.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2021.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2021.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2021.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data_2021['County'] = county_data_2020['County'].str.replace(' County', '')
# Display the filtered data
county_data_2021
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1173032113.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2021.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1173032113.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2021.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\1173032113.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Filter for county-level rows
county_data_2022 = northcarolina_2022[northcarolina_2022["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data_2022.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2022.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2022.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2022.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data_2022.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data_2022['County'] = county_data_2022['County'].str.replace(' County', '')
# Display the filtered data
county_data_2022
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\3291458908.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2022.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\3291458908.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data_2022.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\3291458908.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
northcarolina_ap_2018=county_data_2018[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]
northcarolina_ap_2018['Year'] = '2018'
northcarolina_ap_2019=county_data_2019[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]
northcarolina_ap_2019['Year'] = '2019'
northcarolina_ap_2020=county_data_2020[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]
northcarolina_ap_2020['Year'] = '2020'

northcarolina_ap_2021=county_data_2021[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]
northcarolina_ap_2021['Year'] = '2021'
northcarolina_ap_2022=county_data_2022[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]
northcarolina_ap_2022['Year'] = '2022'

northcarolina_ap_combined=pd.concat([northcarolina_ap_2018, northcarolina_ap_2019, northcarolina_ap_2020, northcarolina_ap_2021, northcarolina_ap_2022], ignore_index=True)
northcarolina_ap_combined
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\879759056.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northcarolina_ap_2018['Year'] = '2018'
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\879759056.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   northcarolina_ap_2019['Year'] = '2019'
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_37548\879759056.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ### Location data for Northcarolina

# %%
northcarolina_counties = uscounties[uscounties['state_id'] == 'NC']
northcarolina_counties=northcarolina_counties.reset_index()
northcarolina_counties=northcarolina_counties[['county','lat','lng','population']]

# %%
carnegie.head()
# Out:
#    Unnamed: 0  unitid                                 name        city stabbr  \
# 0           0  100654             Alabama A & M University      Normal     AL
# 1           1  100663  University of Alabama at Birmingham  Birmingham     AL
# 2           2  100690                   Amridge University  Montgomery     AL
# 3           3  100706  University of Alabama in Huntsville  Huntsville     AL
# 4           4  100724             Alabama State University  Montgomery     AL
#
#    basic2000  basic2005  basic2010  basic2015  basic2018  ...  hbcu  tribal  \
# 0         16         18         18         18         18  ...     1       0
# 1         15         15         15         15         15  ...     0       0
# 2         51         24         24         20         20  ...     0       0
# 3         16         16         15         16         16  ...     0       0
# 4         21         18         18         19         19  ...     1       0
#
#    hsi  msi  womens  rooms  selindex  \
# ...

# %%
northcarolina_counties
# Out:
#          county      lat      lng  population
# 0          Wake  35.7903 -78.6503     1132103
# 1   Mecklenburg  35.2467 -80.8328     1115403
# 2      Guilford  36.0795 -79.7889      539557
# 3       Forsyth  36.1306 -80.2563      383739
# 4    Cumberland  35.0487 -78.8277      335207
# ..          ...      ...      ...         ...
# 95        Gates  36.4449 -76.7005       10509
# 96        Jones  35.0217 -77.3552        9263
# 97       Graham  35.3502 -83.8335        8047
# 98         Hyde  35.5306 -76.2517        4636
# 99      Tyrrell  35.8172 -76.2090        3389
#
# [100 rows x 4 columns]

# %%
northcarolina_ap_combined.columns[:]
# Out:
# Index(['County', 'EXAM_COUNT', 'EXAMS_3_OR_ABOVE', 'PERCENT_3_OR_ABOVE',
#        'Year'],
#       dtype='object')

# %%
northcarolina_counties.columns[:]
# Out:
# Index(['county', 'lat', 'lng', 'population'], dtype='object')

# %%
northcarolina_district=northcarolina_ap_combined

# %%
# Merge the DataFrames on the county names
merged_df = northcarolina_district.merge(northcarolina_counties, left_on='County', right_on='county', how='left')

# %%
# Assign the latitude values to the northcarolina_district DataFrame
northcarolina_district['lat'] = merged_df['lat']
northcarolina_district['lng'] = merged_df['lng']
northcarolina_district.to_csv('../data/North_Carolina/northcarolina_districts.csv')

# %%
northcarolina_district
# Out:
#                   County EXAM_COUNT EXAMS_3_OR_ABOVE PERCENT_3_OR_ABOVE  Year  \
# 0    Alamance-Burlington        993              440          44.310171  2018
# 1              Alexander        171               87          50.877193  2018
# 2              Alleghany          2                *                  *  2018
# 3                  Anson         19                6          31.578947  2018
# 4                   Ashe         97               53          54.639175  2018
# ..                   ...        ...              ...                ...   ...
# 474                Wayne      194.0               64          32.989691  2022
# 475               Wilkes      196.0               75          38.265306  2022
# 476               Wilson      224.0              135          60.267857  2022
# 477               Yadkin       72.0               45               62.5  2022
# 478               Yancey       54.0               39          72.222222  2022
#
#          lat      lng
# ...

# %%
carnegie_full = pd.read_excel('../data/CCIHE2021-PublicData.xlsx',sheet_name='Data')
carnegie_full
# Out:
#       unitid                                               name  \
# 0     100654                           Alabama A & M University
# 1     100663                University of Alabama at Birmingham
# 2     100690                                 Amridge University
# 3     100706                University of Alabama in Huntsville
# 4     100724                           Alabama State University
# ...      ...                                                ...
# 3934  496186  California Institute of Arts & Technology-Nati...
# 3935  999903                     Inter-American Defense College
# 3936  999907                The Judge Advocate General's School
# 3937  999909                     United States Army War College
# 3938  999911                                     Air University
#
#                  city stabbr  basic2000  basic2005  basic2010  basic2015  \
# 0              Normal     AL         16         18         18         18
# ...

# %%
carnegie['stem_rsd'] = carnegie_full['stem_rsd']
carnegie['anenr1920'] = carnegie_full['anenr1920']

# %%
def closest_five(carnegie_univ_data,lat,long):

    # carnegie_univ_data is meant to be sublist/subdataframe of carnegie dataset (with location)
    # lat is meant to be the latitude of the location (usually county)
    # long is meant to be the longitude of the location
    # Returns the average distance to the five closest universities from the supplied list.

    univ_distance = {'unitid':[],'distance':[]}
    for i in carnegie_univ_data.index:
        univ_distance['unitid']=univ_distance['unitid']+[carnegie_univ_data.unitid[i]]
        univ_distance['distance']=univ_distance['distance']+[distance((lat,long),(carnegie_univ_data.latitude[i],carnegie_univ_data.longitude[i])).km]
    univ_distance = pd.DataFrame(univ_distance)
    closest_five = univ_distance.sort_values(by = 'distance')[:5]
    return np.mean(closest_five['distance'].values)

carnegie_r1r2 = carnegie[carnegie['basic2021'].isin([15,16])]
closest_five(carnegie_r1r2,40.902771, -73.133850)  # This is the coordinates of Stony Brook.
# Out:
# np.float64(44.58800478079978)

# %%
northcarolina_counties['closest_five_r1r2_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_r1r2,x.lat, x.lng), axis=1)

# %%
carnegie_public = carnegie[carnegie['control'] == 1]
northcarolina_counties['closest_five_public_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_public,x.lat, x.lng), axis=1)

# %%
carnegie_private_notprofit = carnegie[carnegie['control'] == 2]
northcarolina_counties['closest_five_private_notprofit_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_private_notprofit,x.lat, x.lng), axis=1)

# %%
carnegie_landgrnt = carnegie[carnegie['landgrnt'] == 1]
northcarolina_counties['closest_five_landgrnt_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_landgrnt,x.lat, x.lng), axis=1)

# %%
northcarolina_counties
# Out:
#          county      lat      lng  population  closest_five_r1r2_avg  \
# 0          Wake  35.7903 -78.6503     1132103              58.220189
# 1   Mecklenburg  35.2467 -80.8328     1115403             105.001218
# 2      Guilford  36.0795 -79.7889      539557              39.040931
# 3       Forsyth  36.1306 -80.2563      383739              59.973540
# 4    Cumberland  35.0487 -78.8277      335207             111.096306
# ..          ...      ...      ...         ...                    ...
# 95        Gates  36.4449 -76.7005       10509             118.981300
# 96        Jones  35.0217 -77.3552        9263             134.946532
# 97       Graham  35.3502 -83.8335        8047             135.887955
# 98         Hyde  35.5306 -76.2517        4636             175.657729
# 99      Tyrrell  35.8172 -76.2090        3389             167.823419
#
#     closest_five_public_avg  closest_five_private_notprofit_avg  \
# 0                 23.320156                            3.956381
# ...

# %%
carnegie_stem = carnegie[carnegie['stem_rsd'] > 0] # We define STEM institute to be the one offering at least one STEM research/scholarship doctoral degrees.
northcarolina_counties['closest_five_stem_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_stem,x.lat, x.lng), axis=1)

# %%
def closest_five_enrollment(carnegie_univ_data,lat,long):

    # carnegie_univ_data is meant to be sublist/subdataframe of carnegie dataset (with location and anenr1920)
    # lat is meant to be the latitude of the location (usually county)
    # long is meant to be the longitude of the location
    # Returns the average annual enrollment of the five closest universities from the supplied list.

    univ_enrollment = {'unitid':[],'distance':[],'enrollment':[]}
    for i in carnegie_univ_data.index:
        univ_enrollment['unitid']=univ_enrollment['unitid']+[carnegie_univ_data.unitid[i]]
        univ_enrollment['distance']=univ_enrollment['distance']+[distance((lat,long),(carnegie_univ_data.latitude[i],carnegie_univ_data.longitude[i])).km]
        univ_enrollment['enrollment'] = univ_enrollment['enrollment'] + [carnegie_univ_data['anenr1920'][i]]
    univ_enrollment = pd.DataFrame(univ_enrollment)
    closest_five = univ_enrollment.sort_values(by = 'distance')[:5]
    return np.mean(closest_five['enrollment'].values)
carnegie_r1r2 = carnegie[carnegie['basic2021'].isin([15,16])]
closest_five_enrollment(carnegie_r1r2,40.902771, -73.133850)  # This is the coordinates of Stony Brook.
# Out:
# np.float64(21050.8)

# %%
northcarolina_counties['closest_five_avg_enrollment_r1r2'] = northcarolina_counties.apply(lambda x: closest_five_enrollment(carnegie_r1r2,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_enrollment_public'] = northcarolina_counties.apply(lambda x: closest_five_enrollment(carnegie_public,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_enrollment_private_nfp'] = northcarolina_counties.apply(lambda x: closest_five_enrollment(carnegie_private_notprofit,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_enrollment_landgrnt'] = northcarolina_counties.apply(lambda x: closest_five_enrollment(carnegie_landgrnt,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_enrollment_stem'] = northcarolina_counties.apply(lambda x: closest_five_enrollment(carnegie_stem,x.lat, x.lng), axis=1)

# %%
def closest_five_rooms(carnegie_univ_data,lat,long):
        # carnegie_univ_data is meant to be sublist/subdataframe of carnegie dataset (with location and anenr1920)
    # lat is meant to be the latitude of the location (usually county)
    # long is meant to be the longitude of the location
    # Returns the average dorm rooms of the five closest universities from the supplied list.

    univ_enrollment = {'unitid':[],'distance':[],'rooms':[]}
    for i in carnegie_univ_data.index:
        univ_enrollment['unitid']=univ_enrollment['unitid']+[carnegie_univ_data.unitid[i]]
        univ_enrollment['distance']=univ_enrollment['distance']+[distance((lat,long),(carnegie_univ_data.latitude[i],carnegie_univ_data.longitude[i])).km]
        univ_enrollment['rooms'] = univ_enrollment['rooms'] + [carnegie_univ_data['rooms'][i]]
    univ_enrollment = pd.DataFrame(univ_enrollment)
    closest_five = univ_enrollment.sort_values(by = 'distance')[:5]
    return np.mean(closest_five['rooms'].values)
carnegie_r1r2 = carnegie[carnegie['basic2021'].isin([15,16])]
closest_five_rooms(carnegie_r1r2,40.902771, -73.133850)  # This is the coordinates of Stony Brook.
# Out:
# np.float64(4800.2)

# %%
carnegie.columns[:]
# Out:
# Index(['Unnamed: 0', 'unitid', 'name', 'city', 'stabbr', 'basic2000',
#        'basic2005', 'basic2010', 'basic2015', 'basic2018', 'basic2021',
#        'ipug2021', 'ipgrad2021', 'obereg', 'sector', 'control', 'landgrnt',
#        'medical', 'hbcu', 'tribal', 'hsi', 'msi', 'womens', 'rooms',
#        'selindex', 'address', 'latitude', 'longitude', 'stem_rsd',
#        'anenr1920'],
#       dtype='object')

# %%
northcarolina_counties['closest_five_avg_dormrooms_r1r2'] = northcarolina_counties.apply(lambda x: closest_five_rooms(carnegie_r1r2,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_dormrooms_public'] = northcarolina_counties.apply(lambda x: closest_five_rooms(carnegie_public,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_dormrooms_private_nfp'] = northcarolina_counties.apply(lambda x: closest_five_rooms(carnegie_private_notprofit,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_dormrooms_landgrnt'] = northcarolina_counties.apply(lambda x: closest_five_rooms(carnegie_landgrnt,x.lat, x.lng), axis=1)
northcarolina_counties['closest_five_avg_dormrooms_stem'] = northcarolina_counties.apply(lambda x: closest_five_rooms(carnegie_stem,x.lat, x.lng), axis=1)

# %%
northcarolina_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 19 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   county                                   100 non-null    object
#  1   lat                                      100 non-null    float64
#  2   lng                                      100 non-null    float64
#  3   population                               100 non-null    int64
#  4   closest_five_r1r2_avg                    100 non-null    float64
#  5   closest_five_public_avg                  100 non-null    float64
#  6   closest_five_private_notprofit_avg       100 non-null    float64
#  7   closest_five_landgrnt_avg                100 non-null    float64
#  8   closest_five_stem_avg                    100 non-null    float64
#  9   closest_five_avg_enrollment_r1r2         100 non-null    float64
# ...

# %%
#northcarolina_counties.to_csv('data/North_carolina/train_test_split/northcarolina_closest_five_method.csv')

# %% [markdown]
# ### Income data

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\amahapatra\Documents\data_sc\git_clone_nov19\AP-Outcomes-to-University-Metrics\North_Carolina

# %%
#import sys
#sys.path.insert(1, '../')
import data_loaders_NC

# %%
#import data_loaders
#incomes = pd.read_csv('C:/Users/amahapatra/Documents/data_sc/git_clone_nov19/AP-Outcomes-to-University-Metrics/data/CAINC_Incomes_Counties_2019_2022.csv')
incomes = data_loaders_NC.gimmeCountyIncomes()
incomes = incomes[incomes['State_Abbreviation']=='NC']
#incomes = pd.concat([pd.DataFrame([['Shawano','WI',42033,43883,46611,50004,50444]], columns=incomes.columns), incomes], ignore_index=True)

# %%
incomes
# Out:
#          County State_Abbreviation   2018   2019   2020   2021   2022
# 5852   Alamance                 NC  39318  41182  44223  48218  48980
# 5855  Alexander                 NC  37082  39092  42020  46049  48035
# 5858  Alleghany                 NC  37287  39432  41553  44417  44464
# 5861      Anson                 NC  37416  40772  42032  47342  50187
# 5864       Ashe                 NC  35348  37464  40730  44051  44433
# ...         ...                ...    ...    ...    ...    ...    ...
# 6137      Wayne                 NC  39381  41268  44189  49132  49370
# 6140     Wilkes                 NC  37271  38707  41195  45732  47495
# 6143     Wilson                 NC  40127  41536  44619  48558  48774
# 6146     Yadkin                 NC  37479  39468  41757  46694  47455
# 6149     Yancey                 NC  35814  36935  39418  41798  42006
#
# [100 rows x 7 columns]

# %%
population = data_loaders_NC.gimmeCountyPopulation()
population=population[population['State_Abbreviation']=='NC']
#population = pd.concat([pd.DataFrame([['Shawano','WI',40725,40794,40873,40812,40886]], columns=population.columns), population], ignore_index=True)
population
# Out:
#          County State_Abbreviation    2018    2019    2020    2021    2022
# 5851   Alamance                 NC  166901  169590  171954  173876  176353
# 5854  Alexander                 NC   36459   36499   36482   36467   36512
# 5857  Alleghany                 NC   10928   10867   10897   11066   11185
# 5860      Anson                 NC   22782   21705   22033   22254   22202
# 5863       Ashe                 NC   26641   26671   26580   26764   27110
# ...         ...                ...     ...     ...     ...     ...     ...
# 6136      Wayne                 NC  118048  117792  117266  116866  117286
# 6139     Wilkes                 NC   66715   66316   65904   65818   65784
# 6142     Wilson                 NC   78854   78907   78807   78283   78449
# 6145     Yadkin                 NC   37100   37212   37246   37258   37463
# 6148     Yancey                 NC   18192   18394   18490   18776   18811
#
# [100 rows x 7 columns]

# %%
northcarolina_data = {'county':[],'year':[],'population':[],'per_capita_income':[]}
years = ['2018','2019','2020','2021','2022']
for county in incomes['County'].values:
    for year in years:
        northcarolina_data['county'] = northcarolina_data['county']+[county]
        northcarolina_data['year'] = northcarolina_data['year']+[year]
        northcarolina_data['population'] = northcarolina_data['population']+[int(population[population['County'] == county][year].values[0])]
        northcarolina_data['per_capita_income']= northcarolina_data['per_capita_income']+[int(incomes[incomes['County'] == county][year].values[0])]

northcarolina_data = pd.DataFrame(northcarolina_data)
northcarolina_data
# Out:
#        county  year  population  per_capita_income
# 0    Alamance  2018      166901              39318
# 1    Alamance  2019      169590              41182
# 2    Alamance  2020      171954              44223
# 3    Alamance  2021      173876              48218
# 4    Alamance  2022      176353              48980
# ..        ...   ...         ...                ...
# 495    Yancey  2018       18192              35814
# 496    Yancey  2019       18394              36935
# 497    Yancey  2020       18490              39418
# 498    Yancey  2021       18776              41798
# 499    Yancey  2022       18811              42006
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Combined ap data

# %%
years = ['2018','2019','2020','2021','2022']
pop = []
pci = []
r1r2 = []
public = []
private_notprofit = []
landgrnt  = []
stem  = []
enrollment_r1r2 = []
enrollment_public = []
enrollment_private_nfp = []
enrollment_landgrnt = []
enrollment_stem = []
rooms_r1r2 = []
rooms_public = []
rooms_private_nfp = []
rooms_landgrant = []
rooms_stem = []

for i in northcarolina_ap_combined.index:
    county = northcarolina_ap_combined.iloc[i].County
    year = northcarolina_ap_combined.iloc[i].Year
    
    # Check if the query returns any results before accessing values
    pop_data = northcarolina_data[(northcarolina_data['county'] == county) & (northcarolina_data['year'] == year)]
    if not pop_data.empty:
        pop.append(pop_data.population.values[0])
    else:
        pop.append(None)  # or some default value
    
    pci_data = northcarolina_data[(northcarolina_data['county'] == county) & (northcarolina_data['year'] == year)]
    if not pci_data.empty:
        pci.append(pci_data.per_capita_income.values[0])
    else:
        pci.append(None)  # or some default value
    
    r1r2_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not r1r2_data.empty:
        r1r2.append(r1r2_data.closest_five_r1r2_avg.values[0])
    else:
        r1r2.append(None)  # or some default value
    
    public_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not public_data.empty:
        public.append(public_data.closest_five_public_avg.values[0])
    else:
        public.append(None)  # or some default value
    
    private_notprofit_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not private_notprofit_data.empty:
        private_notprofit.append(private_notprofit_data.closest_five_private_notprofit_avg.values[0])
    else:
        private_notprofit.append(None)  # or some default value

    landgrnt_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not landgrnt_data.empty:
        landgrnt.append(landgrnt_data.closest_five_landgrnt_avg.values[0])
    else:
        landgrnt.append(None)  # or some default value
    
    stem_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not stem_data.empty:
        stem.append(stem_data.closest_five_stem_avg.values[0])
    else:
        stem.append(None)  # or some default value
    
    enrollment_r1r2_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not enrollment_r1r2_data.empty:
        enrollment_r1r2.append(enrollment_r1r2_data.closest_five_avg_enrollment_r1r2.values[0])
    else:
        enrollment_r1r2.append(None)  # or some default value
    
    enrollment_public_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not enrollment_public_data.empty:
        enrollment_public.append(enrollment_public_data.closest_five_avg_enrollment_public.values[0])
    else:
        enrollment_public.append(None)  # or some default value
    
    enrollment_private_nfp_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not enrollment_private_nfp_data.empty:
        enrollment_private_nfp.append(enrollment_private_nfp_data.closest_five_avg_enrollment_private_nfp.values[0])
    else:
        enrollment_private_nfp.append(None)  # or some default value
    
    enrollment_landgrnt_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not enrollment_landgrnt_data.empty:
        enrollment_landgrnt.append(enrollment_landgrnt_data.closest_five_avg_enrollment_landgrnt.values[0])
    else:
        enrollment_landgrnt.append(None)  # or some default value
    
    enrollment_stem_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not enrollment_stem_data.empty:
        enrollment_stem.append(enrollment_stem_data.closest_five_avg_enrollment_stem.values[0])
    else:
        enrollment_stem.append(None)  # or some default value
    
    rooms_r1r2_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not rooms_r1r2_data.empty:
        rooms_r1r2.append(rooms_r1r2_data.closest_five_avg_dormrooms_r1r2.values[0])
    else:
        rooms_r1r2.append(None)  # or some default value
    
    rooms_public_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not rooms_public_data.empty:
        rooms_public.append(rooms_public_data.closest_five_avg_dormrooms_public.values[0])
    else:
        rooms_public.append(None)  # or some default value
    
    rooms_private_nfp_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not rooms_private_nfp_data.empty:
        rooms_private_nfp.append(rooms_private_nfp_data.closest_five_avg_dormrooms_private_nfp.values[0])
    else:
        rooms_private_nfp.append(None)  # or some default value
    
    rooms_landgrant_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not rooms_landgrant_data.empty:
        rooms_landgrant.append(rooms_landgrant_data.closest_five_avg_dormrooms_landgrnt.values[0])
    else:
        rooms_landgrant.append(None)  # or some default value

    rooms_stem_data = northcarolina_counties[northcarolina_counties['county'] == county]
    if not rooms_stem_data.empty:
        rooms_stem.append(rooms_stem_data.closest_five_avg_dormrooms_stem.values[0])
    else:
        rooms_stem.append(None)  # or some default value
northcarolina_ap_combined['population'] = pop
northcarolina_ap_combined['per_capita_income'] = pci
northcarolina_ap_combined['closest_five_r1r2_avg'] = r1r2
northcarolina_ap_combined['closest_five_public_avg'] = public
northcarolina_ap_combined['closest_five_private_notprofit_avg'] = private_notprofit

# %%
northcarolina_ap_combined['closest_five_landgrnt_avg'] = landgrnt
northcarolina_ap_combined['closest_five_stem_avg'] = stem
northcarolina_ap_combined['closest_five_avg_enrollment_r1r2'] = enrollment_r1r2
northcarolina_ap_combined['closest_five_avg_enrollment_public'] = enrollment_public
northcarolina_ap_combined['closest_five_avg_enrollment_private_nfp'] = enrollment_private_nfp
northcarolina_ap_combined['closest_five_avg_enrollment_landgrnt'] = enrollment_landgrnt
northcarolina_ap_combined['closest_five_avg_enrollment_stem'] = enrollment_stem
northcarolina_ap_combined['closest_five_avg_dormrooms_r1r2'] = rooms_r1r2
northcarolina_ap_combined['closest_five_avg_dormrooms_public'] = rooms_public
northcarolina_ap_combined['closest_five_avg_dormrooms_private_nfp'] = rooms_private_nfp
northcarolina_ap_combined['closest_five_avg_dormrooms_landgrant'] = rooms_landgrant
northcarolina_ap_combined['closest_five_avg_dormrooms_stem'] = rooms_stem

# %%
northcarolina_ap_combined
# Out:
#                   County EXAM_COUNT EXAMS_3_OR_ABOVE PERCENT_3_OR_ABOVE  Year  \
# 0    Alamance-Burlington        993              440          44.310171  2018
# 1              Alexander        171               87          50.877193  2018
# 2              Alleghany          2                *                  *  2018
# 3                  Anson         19                6          31.578947  2018
# 4                   Ashe         97               53          54.639175  2018
# ..                   ...        ...              ...                ...   ...
# 474                Wayne      194.0               64          32.989691  2022
# 475               Wilkes      196.0               75          38.265306  2022
# 476               Wilson      224.0              135          60.267857  2022
# 477               Yadkin       72.0               45               62.5  2022
# 478               Yancey       54.0               39          72.222222  2022
#
# ...

# %%
northcarolina_ap_combined
# Out:
#                   County EXAM_COUNT EXAMS_3_OR_ABOVE PERCENT_3_OR_ABOVE  Year  \
# 0    Alamance-Burlington        993              440          44.310171  2018
# 1              Alexander        171               87          50.877193  2018
# 2              Alleghany          2                *                  *  2018
# 3                  Anson         19                6          31.578947  2018
# 4                   Ashe         97               53          54.639175  2018
# ..                   ...        ...              ...                ...   ...
# 474                Wayne      194.0               64          32.989691  2022
# 475               Wilkes      196.0               75          38.265306  2022
# 476               Wilson      224.0              135          60.267857  2022
# 477               Yadkin       72.0               45               62.5  2022
# 478               Yancey       54.0               39          72.222222  2022
#
# ...

# %% [markdown]
# ### "northcarolina_ap_combined" is the dataframe that we will use for statistical analysis. So, we save it as a csv file.

# %%
northcarolina_ap_combined.to_csv('../data/North_Carolina/train_test_split/northcarolina_closest_five_method.csv')

# %% [markdown]
# ### NN model

# %%
import seaborn as sns
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming northcarolina_ap_combined is your DataFrame
training, testing = train_test_split(northcarolina_ap_combined, test_size=0.2, random_state=100)
features = ['population', 'per_capita_income', 'closest_five_r1r2_avg', 'closest_five_public_avg', 'closest_five_private_notprofit_avg']

# %%
# Check and convert data types
training['PERCENT_3_OR_ABOVE'] = pd.to_numeric(training['PERCENT_3_OR_ABOVE'], errors='coerce')
training['population'] = pd.to_numeric(training['population'], errors='coerce')

# %%
# Handle missing values
training = training.dropna(subset=['PERCENT_3_OR_ABOVE', 'population'])

# %%
# Verify data
print(training[['PERCENT_3_OR_ABOVE', 'population']].head())
# Out:
#      PERCENT_3_OR_ABOVE  population
# 78            43.373494     59748.0
# 430           70.689655     42955.0
# 197           36.956522     17848.0
# 149           49.683944     85810.0
# 31            17.045455     50251.0

# %%
# Plot
sns.lmplot(data=training, x='PERCENT_3_OR_ABOVE', y='population')

# %%
sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='per_capita_income')

# %%
sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_r1r2_avg')

# %%
sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_public_avg')

# %%
sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_private_notprofit_avg')

# %% [markdown]
# ### csv files of train and test the dataframe

# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
training, testing = train_test_split(northcarolina_ap_combined, test_size = 0.2, random_state = 226)
training.to_csv('data/North_Carolina/train_test_split/training.csv')
testing.to_csv('data/North_Carolina/train_test_split/testing.csv')

# %% [markdown]
# ### data for 2023

# %%
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# training, testing = train_test_split(northcarolina_ap_combined, test_size = 0.2, random_state = 100)
# features = ['population','per_capita_income','closest_five_r1r2_avg','closest_five_public_avg','closest_five_private_notprofit_avg']
# sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='population')

# %%
northcarolina_2023=pd.read_excel('data/North_Carolina/2023_AP Test Results_2023.xlsx',sheet_name='fortablebysch3yrs_2223_final')

# %%
northcarolina_counties
# Out:
#          county      lat      lng  population  closest_five_r1r2_avg  \
# 0          Wake  35.7903 -78.6503     1132103              58.220189
# 1   Mecklenburg  35.2467 -80.8328     1115403             105.001218
# 2      Guilford  36.0795 -79.7889      539557              39.040931
# 3       Forsyth  36.1306 -80.2563      383739              59.973540
# 4    Cumberland  35.0487 -78.8277      335207             111.096306
# ..          ...      ...      ...         ...                    ...
# 95        Gates  36.4449 -76.7005       10509             118.981300
# 96        Jones  35.0217 -77.3552        9263             134.946532
# 97       Graham  35.3502 -83.8335        8047             135.887955
# 98         Hyde  35.5306 -76.2517        4636             175.657729
# 99      Tyrrell  35.8172 -76.2090        3389             167.823419
#
#     closest_five_public_avg  closest_five_private_notprofit_avg  \
# 0                 23.320156                            3.956381
# ...

# %%
#northcarolina_2023.iloc[1:30]

# %%
#northcarolina_2018=pd.read_excel('data/North_Carolina/AP_Test_Results_2018.xlsx',sheet_name='2018')

# %%
#northcarolina_2018

# %%
# # Filter for county-level rows
# county_data_2018 = northcarolina_2018[northcarolina_2018["School System & School"].str.contains("County", na=False)]

# # Reset the index
# county_data_2018.reset_index(drop=True, inplace=True)

# # Rename the 'School System & School' column to 'County'
# county_data_2018.rename(columns={'School System & School': 'County'}, inplace=True)

# # Rename the 'School System & School' column to 'County'
# county_data_2018.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# # Rename the 'School System & School' column to 'County'
# county_data_2018.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# # Rename the 'School System & School' column to 'County'
# county_data_2018.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# # Remove the word 'County' from the entries in the 'County' column
# county_data_2018['County'] = county_data['County'].str.replace(' County', '')
# # Display the filtered data
# county_data_2018

# %%
# Filter for county-level rows
county_data = northcarolina_2023[northcarolina_2023["School System & School"].str.contains("County", na=False)]

# Reset the index
county_data.reset_index(drop=True, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data.rename(columns={'School System & School': 'County'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data.rename(columns={'# of Test-taker Scoring 3 or Higher3': 'EXAMS_3_OR_ABOVE'}, inplace=True)

# Rename the 'School System & School' column to 'County'
county_data.rename(columns={'% of Test-Takers Scoring 3 or Higher4': 'PERCENT_3_OR_ABOVE'}, inplace=True)


# Remove the word 'County' from the entries in the 'County' column
county_data['County'] = county_data['County'].str.replace(' County', '')
# Display the filtered data
county_data
# Out:
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_3640\348150843.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data.rename(columns={'School System & School': 'County'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_3640\348150843.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_data.rename(columns={'# of Test Takers1': 'EXAM_COUNT'}, inplace=True)
# C:\Users\amahapatra\AppData\Local\Temp\ipykernel_3640\348150843.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
northcarolina_ap=county_data[['County','EXAM_COUNT','EXAMS_3_OR_ABOVE','PERCENT_3_OR_ABOVE']]

# %%
northcarolina_ap
# Out:
#         County EXAM_COUNT EXAMS_3_OR_ABOVE PERCENT_3_OR_ABOVE
# 0    Alexander        109               79          72.477064
# 1    Alleghany        NaN              NaN                NaN
# 2        Anson         43                6          13.953488
# 3         Ashe         94               59          62.765957
# 4    Ashe High         94               59          62.765957
# ..         ...        ...              ...                ...
# 103      Wayne        195               69          35.384615
# 104     Wilkes        160               59          36.645963
# 105     Wilson        245              154          62.857143
# 106     Yadkin         18               13          72.222222
# 107     Yancey         75               65          86.666667
#
# [108 rows x 4 columns]

# %%
northcarolina_data
# Out:
#        county  year  population  per_capita_income
# 0    Alamance  2018      166901              39318
# 1    Alamance  2019      169590              41182
# 2    Alamance  2020      171954              44223
# 3    Alamance  2021      173876              48218
# 4    Alamance  2022      176353              48980
# ..        ...   ...         ...                ...
# 495    Yancey  2018       18192              35814
# 496    Yancey  2019       18394              36935
# 497    Yancey  2020       18490              39418
# 498    Yancey  2021       18776              41798
# 499    Yancey  2022       18811              42006
#
# [500 rows x 4 columns]

# %%
# years = ['2018','2019','2020','2021','2022']
# pop = []
# pci = []
# r1r2 = []
# public = []
# private_notprofit = []

# for i in northcarolina_ap_combined.index:
#     county = northcarolina_ap_combined.iloc[i].County
#     year = northcarolina_ap_combined.iloc[i].Year
    
#     # Check if the query returns any results before accessing values
#     pop_data = northcarolina_data[(northcarolina_data['county'] == county) & (northcarolina_data['year'] == year)]
#     if not pop_data.empty:
#         pop.append(pop_data.population.values[0])
#     else:
#         pop.append(None)  # or some default value
    
#     pci_data = northcarolina_data[(northcarolina_data['county'] == county) & (northcarolina_data['year'] == year)]
#     if not pci_data.empty:
#         pci.append(pci_data.per_capita_income.values[0])
#     else:
#         pci.append(None)  # or some default value
    
#     r1r2_data = northcarolina_counties[northcarolina_counties['county'] == county]
#     if not r1r2_data.empty:
#         r1r2.append(r1r2_data.closest_five_r1r2_avg.values[0])
#     else:
#         r1r2.append(None)  # or some default value
    
#     public_data = northcarolina_counties[northcarolina_counties['county'] == county]
#     if not public_data.empty:
#         public.append(public_data.closest_five_public_avg.values[0])
#     else:
#         public.append(None)  # or some default value
    
#     private_notprofit_data = northcarolina_counties[northcarolina_counties['county'] == county]
#     if not private_notprofit_data.empty:
#         private_notprofit.append(private_notprofit_data.closest_five_private_notprofit_avg.values[0])
#     else:
#         private_notprofit.append(None)  # or some default value

# northcarolina_ap_combined['population'] = pop
# northcarolina_ap_combined['per_capita_income'] = pci
# northcarolina_ap_combined['closest_five_r1r2_avg'] = r1r2
# northcarolina_ap_combined['closest_five_public_avg'] = public
# northcarolina_ap_combined['closest_five_private_notprofit_avg'] = private_notprofit

# %%
#northcarolina_ap

# %%
# pop = []

# for i in range(2, 5):
#     county = northcarolina_ap.iloc[i].County
#     year = '2018'  # Make sure to define the year variable
    
#     # Check if the query returns any results before accessing values
#     pop_data = northcarolina_data[(northcarolina_data['county'] == county) & (northcarolina_data['year'] == year)]
#     if not pop_data.empty:
#         pop.append(pop_data.population.values[0])
#     else:
#         pop.append(None)  # or some default value

# pop

# %%
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# training, testing = train_test_split(northcarolina_ap, test_size = 0.2, random_state = 100)
# features = ['population','per_capita_income','closest_five_r1r2_avg','closest_five_public_avg','closest_five_private_notprofit_avg']
# sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='population')

# %%
# import seaborn as sns
# import pandas as pd
# from sklearn.model_selection import train_test_split

# # Assuming 'northcarolina_ap' is your DataFrame
# # Split the data into training and testing sets
# training, testing = train_test_split(northcarolina_ap, test_size=0.2, random_state=300)

# # Define the features you are interested in
# features = ['population', 'per_capita_income', 'closest_five_r1r2_avg', 'closest_five_public_avg', 'closest_five_private_notprofit_avg']

# # Replace non-numeric values with NaN and then drop them in the training set
# training['population'] = pd.to_numeric(training['population'], errors='coerce')
# training['PERCENT_3_OR_ABOVE'] = pd.to_numeric(training['PERCENT_3_OR_ABOVE'], errors='coerce')

# # Drop rows with NaN values in the columns of interest
# training_cleaned = training.dropna(subset=['population', 'PERCENT_3_OR_ABOVE'])

# # Create a linear model plot using Seaborn
# sns.lmplot(data=training_cleaned, x='PERCENT_3_OR_ABOVE', y='population')

# %%
#sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='per_capita_income')

# %%
# sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_r1r2_avg')

# %%
# sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_public_avg')

# %%
# sns.lmplot(data = training, x='PERCENT_3_OR_ABOVE',y='closest_five_private_notprofit_avg')

# %%
# northcarolina_data

# %%
# northcarolina_counties

# %%
# carnegie[carnegie['basic2021'].isin([15,16])]

# %%
# def closest_five(carnegie_univ_data,lat,long):

#     # carnegie_univ_data is meant to be sublist/subdataframe of carnegie dataset (with location)
#     # lat is meant to be the latitude of the location (usually county)
#     # long is meant to be the longitude of the location
#     # Returns the average distance to the five closest universities from the supplied list.

#     univ_distance = {'unitid':[],'distance':[]}
#     for i in carnegie_univ_data.index:
#         univ_distance['unitid']=univ_distance['unitid']+[carnegie_univ_data.unitid[i]]
#         univ_distance['distance']=univ_distance['distance']+[distance((lat,long),(carnegie_univ_data.latitude[i],carnegie_univ_data.longitude[i])).km]
#     univ_distance = pd.DataFrame(univ_distance)
#     closest_five = univ_distance.sort_values(by = 'distance')[:5]
#     return np.mean(closest_five['distance'].values)

# carnegie_r1r2 = carnegie[carnegie['basic2021'].isin([15,16])]
# closest_five(carnegie_r1r2,40.902771, -73.133850)  # This is the coordinates of Stony Brook.

# %%
# northcarolina_counties['closest_five_r1r2_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_r1r2,x.lat, x.lng), axis=1)

# %%
# northcarolina_counties

# %%
# carnegie_public = carnegie[carnegie['control'] == 1]
# northcarolina_counties['closest_five_public_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_public,x.lat, x.lng), axis=1)

# %%
# carnegie_private_notprofit = carnegie[carnegie['control'] == 2]
# northcarolina_counties['closest_five_private_notprofit_avg'] = northcarolina_counties.apply(lambda x: closest_five(carnegie_private_notprofit,x.lat, x.lng), axis=1)

# %%
# northcarolina_counties

# %%
# import data_loaders
# incomes = data_loaders.gimmeCountyIncomes()
# incomes = incomes[incomes['State_Abbreviation']=='NC']
# #incomes = pd.concat([pd.DataFrame([['Shawano','WI',42033,43883,46611,50004,50444]], columns=incomes.columns), incomes], ignore_index=True)

# %%
# incomes

# %%
#county_data[county_data['County'].isin(incomes['County'].values) == False]

# %%
# population = data_loaders.gimmeCountyPopulation()
# population=population[population['State_Abbreviation']=='NC']
# #population = pd.concat([pd.DataFrame([['Shawano','WI',40725,40794,40873,40812,40886]], columns=population.columns), population], ignore_index=True)
# population

# %%
# northcarolina_data = {'county':[],'year':[],'population':[],'per_capita_income':[]}
# years = ['2018','2019','2020','2021','2022']
# for county in incomes['County'].values:
#     for year in years:
#         northcarolina_data['county'] = northcarolina_data['county']+[county]
#         northcarolina_data['year'] = northcarolina_data['year']+[year]
#         northcarolina_data['population'] = northcarolina_data['population']+[int(population[population['County'] == county][year].values[0])]
#         northcarolina_data['per_capita_income']= northcarolina_data['per_capita_income']+[int(incomes[incomes['County'] == county][year].values[0])]

# %%
# northcarolina_data = pd.DataFrame(northcarolina_data)
# northcarolina_data

# %%
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# training, testing = train_test_split(northcarolina_ap_combined, test_size = 0.2, random_state = 226)
# training.to_csv('data/North_Carolina/train_test_split/training.csv')
# testing.to_csv('data/North_Carolina/train_test_split/testing.csv')

# %%
# from sklearn.model_selection import train_test_split
# training, testing = train_test_split(northcarolina_ap_combined, test_size = 0.2, random_state = 226)

# %%
# training.to_csv('data/North_Carolina/train_test_split/training.csv')

# %%
# testing.to_csv('data/North_Carolina/train_test_split/testing.csv')
